# %%
from ssd import build_ssd

## box_utils裡面很多Function，可以看看是怎麼設計的
from layers.box_utils import * 
from torch.autograd import Variable
from layers import functions
from layers import modules
from math import sqrt 
from itertools import product
from torch.autograd import Function

import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import argparse
import pickle
import torch.nn.functional as F

# %%
## 詳細模型結構可以參考ssd.py
ssd_net=build_ssd('train', size=300, num_classes=21)
# Out:
# C:\Users\User\Documents\1st-DL-CVMarathon\homework\Object Detection 程式導讀\ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)

# %% [markdown]
# ## 默認Config檔案在data/config.py內

# %%
ssd_net.cfg
# Out:
# {'num_classes': 21,
#  'lr_steps': (80000, 100000, 120000),
#  'max_iter': 120000,
#  'feature_maps': [38, 19, 10, 5, 3, 1],
#  'min_dim': 300,
#  'steps': [8, 16, 32, 64, 100, 300],
#  'min_sizes': [30, 60, 111, 162, 213, 264],
#  'max_sizes': [60, 111, 162, 213, 264, 315],
#  'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
#  'variance': [0.1, 0.2],
#  'clip': True,
#  'name': 'VOC'}

# %%
cfg = {
    'num_classes': 21,
    'lr_steps': (80000, 100000, 120000),
    'max_iter': 120000,
    'feature_maps': [38, 19, 10, 5, 3, 1],
    'min_dim': 300,
    'steps': [8, 16, 32, 64, 100, 300],
    'min_sizes': [30, 60, 111, 162, 213, 264],
    'max_sizes': [60, 111, 162, 213, 264, 315],
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
    'variance': [0.1, 0.2],
    'clip': True,
    'name': 'VOC',
}

# %% [markdown]
# ### 'aspect_ratios' : 使用六張Feature Map，每一張上方有預設的anchor boxes，Boxes aspect ratio可以自己設定
# ### 'feature_maps' : 使用feature map大小為[38x38, 19x19, 10x10, 5x5, 3x3, 1x1]
# ### 'min_sizes'、'max_sizes'可藉由下方算式算出，由作者自行設計
# ### 'steps' : Feature map回放回原本300*300的比例，如38要回放為300大概就是8倍
# ### 'variance' : Training 的一個trick，加速收斂，詳見：https://github.com/rykov8/ssd_keras/issues/53

# %% [markdown]
# ---

# %% [markdown]
# ## 'min_sizes'、'max_sizes' 計算

# %%
import math
## source:https://blog.csdn.net/gbyy42299/article/details/81235891
min_dim = 300   ## 维度
# conv4_3 ==> 38 x 38
# fc7 ==> 19 x 19
# conv6_2 ==> 10 x 10
# conv7_2 ==> 5 x 5
# conv8_2 ==> 3 x 3
# conv9_2 ==> 1 x 1
mbox_source_layers = ['conv4_3', 'fc7', 'conv6_2', 'conv7_2', 'conv8_2', 'conv9_2'] ## prior_box來源層，可以更改。很多改進都是基於此處的調整。
# in percent %
min_ratio = 20 ## 這裡即是論文中所說的Smin的= 0.2，Smax的= 0.9的初始值，經過下面的運算即可得到min_sizes，max_sizes。
max_ratio = 90
step = int(math.floor((max_ratio - min_ratio) / (len(mbox_source_layers) - 2)))## 取一個間距步長，即在下面用於循環給比取值時起一個間距作用。可以用一個具體的數值代替，這裡等於17。
min_sizes = []  ## 經過以下運算得到min_sizes和max_sizes。
max_sizes = []
for ratio in range(min_ratio, max_ratio + 1, step):
    ## 從min_ratio至max_ratio + 1每隔步驟= 17取一個值賦值給比。注意範圍函數的作用。
    ## min_sizes.append（）函數即把括號內部每次得到的值依次給了min_sizes。
    min_sizes.append(min_dim * ratio / 100.)
    max_sizes.append(min_dim * (ratio + step) / 100.)
min_sizes = [min_dim * 10 / 100.] + min_sizes
max_sizes = [min_dim * 20 / 100.] + max_sizes

## steps: 這一步要仔細理解，即計算卷積層產生的prior_box距離原圖的步長，先驗框中心點的坐標會乘以step，
## 相當於從特徵映射位置映射回原圖位置，比如conv4_3輸出特徵圖大小為38 *38，而輸入的圖片為300* 300，
## 所以38 *8約等於300，所以映射步長為8.這是針對300* 300的訓練圖片。
steps = [8, 16, 32, 64, 100, 300]  
aspect_ratios = [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
 
print('min_sizes: ',min_sizes)
print('max_sizes: ',max_sizes)
# Out:
# min_sizes:  [30.0, 60.0, 111.0, 162.0, 213.0, 264.0]
# max_sizes:  [60.0, 111.0, 162.0, 213.0, 264.0, 315.0]

# %% [markdown]
# ---

# %% [markdown]
# ## Default anchor boxes設計原理，看懂收穫很多
# ##### 可以理解 SSD原文中 8732個anchors是怎麼來的
# ##### 38×38×4+19×19×6+10×10×6+5×5×6+3×3×4+1×1×4=8732

# %%
class PriorBox(object):
    """Compute priorbox coordinates in center-offset form for each source
    feature map.
    """
    def __init__(self, cfg):
        super(PriorBox, self).__init__()
        self.image_size = cfg['min_dim']
        # number of priors for feature map location (either 4 or 6)
        self.num_priors = len(cfg['aspect_ratios'])
        self.variance = cfg['variance'] or [0.1]
        self.feature_maps = cfg['feature_maps']
        self.min_sizes = cfg['min_sizes']
        self.max_sizes = cfg['max_sizes']
        self.steps = cfg['steps']
        self.aspect_ratios = cfg['aspect_ratios']
        self.clip = cfg['clip']
        self.version = cfg['name']
        for v in self.variance:
            if v <= 0:
                raise ValueError('Variances must be greater than 0')

    def forward(self):
        mean = []
        '''依照Feature map大小找出所有的pixel 中心'''
        '''下方這兩個loop會找出W個x軸pixel對上W個y軸pixel，假如現在是在38x38的feature map上，就會有38x38個值'''
        '''ex. [0,1],[0,2]..[0,37] [1,1],[1,2]..[1,37]..........[37,37]'''
        for k, f in enumerate(self.feature_maps):
            for i, j in product(range(f), repeat=2):
                f_k = self.image_size / self.steps[k] ## 如self.steps==8，就是先將原圖size normalize(/300)後再乘上8
                # unit center x,y
                '''中心點'''
                cx = (j + 0.5) / f_k
                cy = (i + 0.5) / f_k

                # aspect_ratio: 1
                # rel size: min_size
                '''/self.image_size 就是在做normalization '''
                s_k = self.min_sizes[k]/self.image_size
                '''小的正方形box'''
                mean += [cx, cy, s_k, s_k]

                # aspect_ratio: 1
                # rel size: sqrt(s_k * s_(k+1))
                '''大的正方形box'''
                s_k_prime = sqrt(s_k * (self.max_sizes[k]/self.image_size))
                mean += [cx, cy, s_k_prime, s_k_prime]

                # rest of aspect ratios
                for ar in self.aspect_ratios[k]:
                    '''aspect ratio 2,3'''
                    mean += [cx, cy, s_k*sqrt(ar), s_k/sqrt(ar)]
                    '''aspect ratio 1/2,1/3'''
                    mean += [cx, cy, s_k/sqrt(ar), s_k*sqrt(ar)]
        # back to torch land
        output = torch.Tensor(mean).view(-1, 4)
        if self.clip:
            output.clamp_(max=1, min=0)
        return output

# %%
PriorBox_Demo=PriorBox(cfg)

# %%
print(PriorBox_Demo.forward().shape)
# Out:
# torch.Size([8732, 4])

# %% [markdown]
# ---

# %% [markdown]
# ## Loss 如何設計

# %%
class MultiBoxLoss(nn.Module):

    def __init__(self, num_classes, overlap_thresh, prior_for_matching,
                 bkg_label, neg_mining, neg_pos, neg_overlap, encode_target,
                 use_gpu=True):
        super(MultiBoxLoss, self).__init__()
        self.use_gpu = use_gpu
        '''有幾類'''
        self.num_classes = num_classes
        '''判定為正樣本的threshold，一般設為0.5'''
        self.threshold = overlap_thresh
        '''background自己會有一類，不用Label，假如我們有20類一樣標註0-19，下方會自己空出一類給background'''
        self.background_label = bkg_label
        self.encode_target = encode_target
        self.use_prior_for_matching = prior_for_matching
        '''OHEM，找出分得最不好的樣品，也就是confidence score比較低的正負樣品'''
        self.do_neg_mining = neg_mining
        '''負樣品與正樣品的比例，通常是3:1'''
        self.negpos_ratio = neg_pos
        self.neg_overlap = neg_overlap
        self.variance = cfg['variance']
     

    def forward(self, predictions, targets):

        '''prediction會output三個值'''
        '''loc shape: bounding box 資訊，torch.size(batch_size,num_priors,4)'''
        '''conf shape: 每一個bounding box 的信心程度，torch.size(batch_size,num_priors,num_classes)'''
        '''priors shape: 預設的defaul box， torch.size(num_priors,4)'''
        loc_data, conf_data, priors = predictions
        num = loc_data.size(0)
        priors = priors[:loc_data.size(1), :]
        num_priors = (priors.size(0))
        num_classes = self.num_classes

        # match priors (default boxes) and ground truth boxes
        loc_t = torch.Tensor(num, num_priors, 4)
        conf_t = torch.LongTensor(num, num_priors)
        for idx in range(num):
            truths = targets[idx][:, :-1].data
            labels = targets[idx][:, -1].data
            defaults = priors.data
            '''jaccard 計算每一個BBOX與ground truth的IOU'''
            match(self.threshold, truths, defaults, self.variance, labels,
                  loc_t, conf_t, idx)
        if self.use_gpu:
            loc_t = loc_t.cuda()
            conf_t = conf_t.cuda()
        '''用Variable包裝'''
        loc_t = Variable(loc_t, requires_grad=False)
        conf_t = Variable(conf_t, requires_grad=False)

        pos = conf_t > 0
        num_pos = pos.sum(dim=1, keepdim=True)


        pos_idx = pos.unsqueeze(pos.dim()).expand_as(loc_data)
        loc_p = loc_data[pos_idx].view(-1, 4)
        loc_t = loc_t[pos_idx].view(-1, 4)
        '''smooth_l1_loss 計算bounding box regression'''
        loss_l = F.smooth_l1_loss(loc_p, loc_t, size_average=False)

        # Compute max conf across batch for hard negative mining
        batch_conf = conf_data.view(-1, self.num_classes)
        loss_c = log_sum_exp(batch_conf) - batch_conf.gather(1, conf_t.view(-1, 1))

        # Hard Negative Mining
        loss_c = loss_c.view(num, -1)
        loss_c[pos] = 0
        '''排列confidence 的分數'''
        _, loss_idx = loss_c.sort(1, descending=True)
        _, idx_rank = loss_idx.sort(1)
        num_pos = pos.long().sum(1, keepdim=True)
        '''負樣品取出數量 == negpos_ratio*num_pos'''
        num_neg = torch.clamp(self.negpos_ratio*num_pos, max=pos.size(1)-1)
        neg = idx_rank < num_neg.expand_as(idx_rank)

        # Confidence Loss Including Positive and Negative Examples
        pos_idx = pos.unsqueeze(2).expand_as(conf_data)
        neg_idx = neg.unsqueeze(2).expand_as(conf_data)
        conf_p = conf_data[(pos_idx+neg_idx).gt(0)].view(-1, self.num_classes)
        targets_weighted = conf_t[(pos+neg).gt(0)]
        '''用cross_entropy做分類'''
        loss_c = F.cross_entropy(conf_p, targets_weighted, size_average=False)

        # Sum of losses: L(x,c,l,g) = (Lconf(x, c) + αLloc(x,l,g)) / N
        #double轉成torch.float64
        N = num_pos.data.sum().double()
        loss_l = loss_l.double()
        loss_c = loss_c.double()
        loss_l /= N
        loss_c /= N
        return loss_l, loss_c

# %% [markdown]
# ## 產生我們Loss function，注意這裡的class要包含背景

# %%
Use_cuda=False
criterion = MultiBoxLoss(21, 0.5, True, 0, False, 3, 0.5,False, Use_cuda,)

# %% [markdown]
# ----

# %% [markdown]
# ## 基本設定

# %%
ssd_net=build_ssd('train', size=300, num_classes=21)
use_pretrained=False
if use_pretrained:
    ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
net=ssd_net

# %%
'''要不要使用gpu'''
Use_cuda=False

'''tensor type會依照cpu或gpu有所不同'''
if torch.cuda.is_available():
    if Use_cuda:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
    else:
        print("WARNING: It looks like you have a CUDA device, but aren't " +
              "using CUDA.\nRun with --cuda for optimal training speed.")
        torch.set_default_tensor_type('torch.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')


'''使用GPU時模型要轉成cuda'''
if Use_cuda:
    net = net.cuda()
    
batch_size_=32
optimizer = optim.Adam(net.parameters(),lr=0.00001/batch_size_)
# Out:
# WARNING: It looks like you have a CUDA device, but aren't using CUDA.
# Run with --cuda for optimal training speed.

# %% [markdown]
# ---

# %% [markdown]
# ## 訓練

# %% [markdown]
# ## 這裡我們先示範輸入的 image,Label格式，真正在訓練時，準備成一樣格式即可

# %%
'''輸入影像格式，假設batch size 為 4'''
image_in=torch.tensor(torch.rand(4,3,300,300),dtype=torch.float32)
'''Label格式，沒有固定長度，看圖像中有幾個label就有幾個'''
label_0=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_1=[[ 0.1804,  0.6076,  0.7701,  0.8485, 13.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 11.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 7.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 5.0000],]
label_2=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 14.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_3=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
# Out:
# C:\Users\User\Documents\1st-DL-CVMarathon\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
epochs=300
iteration=1000

# %%
for epoch in range(epochs):
    n=0
    loss_sum=[]
    loc_loss=[]
    conf_loss=[]
    for number__ in range(iteration) :
        '''要用Variable包裝tensor才能送入模型'''
        if Use_cuda:
            image_ = Variable(image_in.cuda())
            y = [Variable(torch.tensor(label_0).cuda(), volatile=True),Variable(torch.tensor(label_1).cuda(), 
                volatile=True),Variable(torch.tensor(label_2).cuda(), volatile=True),Variable(torch.tensor(label_3).cuda(), volatile=True)]      
        else:
            image_ = Variable(image_in)
            y = [Variable(torch.tensor(label_0), volatile=True),Variable(torch.tensor(label_1), 
                volatile=True),Variable(torch.tensor(label_2), volatile=True),Variable(torch.tensor(label_3), volatile=True)]

        '''Forward Pass'''
        out = net(image_)
        '''Regression Loss and Classification Loss'''
        loss_l,loss_c = criterion(out,y )
        loss = loss_l+ loss_c
        '''Backward'''
        loss.backward()

        loc_loss.append(loss_l.data.cpu().numpy())
        conf_loss.append(loss_c.data.cpu().numpy())
        loss_sum.append(loss.data.cpu().numpy())
        '''更新參數'''
        optimizer.step()
        '''清空Gradients'''
        optimizer.zero_grad()
        
        n+=1
        if n%10==0:
            print('BBOX Regression Loss: ', np.mean(loc_loss))
            print('Classification Loss: ', np.mean(conf_loss))
    '''儲存權重'''
    torch.save(ssd_net.state_dict(),'weights/Ｗeights.pth')
# Out:
# C:\Users\User\Documents\1st-DL-CVMarathon\lib\site-packages\ipykernel_launcher.py:14: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# C:\Users\User\Documents\1st-DL-CVMarathon\lib\site-packages\ipykernel_launcher.py:15: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   from ipykernel import kernelapp as app
# C:\Users\User\Documents\1st-DL-CVMarathon\lib\site-packages\torch\nn\_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# BBOX Regression Loss:  2.5133396289966727
# Classification Loss:  14.277714256004051
# BBOX Regression Loss:  2.5132073579011136
# Classification Loss:  14.182458157009549
# BBOX Regression Loss:  2.513075689621913
# Classification Loss:  14.090385719581885
# BBOX Regression Loss:  2.5129437340630423
# Classification Loss:  14.002485684995298
# BBOX Regression Loss:  2.5128117935745804
# Classification Loss:  13.920101092303241
# BBOX Regression Loss:  2.51267978997878
# Classification Loss:  13.842878289870274
# BBOX Regression Loss:  2.5125476372935776
# Classification Loss:  13.770498931723296
# BBOX Regression Loss:  2.5124154267487704
# Classification Loss:  13.701123880456995
# BBOX Regression Loss:  2.5122831870498974
# Classification Loss:  13.634136284722219
# BBOX Regression Loss:  2.512151059751157
# Classification Loss:  13.569042799207898
# BBOX Regression Loss:  2.5120189294269193
# Classification Loss:  13.505413715606588
# BBOX Regression Loss:  2.5118868933783642
# Classification Loss:  13.442896694607205
# BBOX Regression Loss:  2.5117548059534136
# Classification Loss:  13.381241922840434
# BBOX Regression Loss:  2.5116226519226394
# Classification Loss:  13.320269484747024
# BBOX Regression Loss:  2.5114905011212385
# Classification Loss:  1.062667628589627
# BBOX Regression Loss:  0.009939151820956648
# Classification Loss:  1.0565900206565857
# BBOX Regression Loss:  0.009776896175534908
# Classification Loss:  1.05073760790259
# BBOX Regression Loss:  0.009623298583759201
# Classification Loss:  1.0451064430519386
# BBOX Regression Loss:  0.009471758292986588
# Classification Loss:  1.0395465482380744
# BBOX Regression Loss:  0.009321437892305037
# Classification Loss:  1.0341623461144602
# BBOX Regression Loss:  0.009174578785531842
# Classification Loss:  1.028973845315929
# BBOX Regression Loss:  0.009031219077545675
# Classification Loss:  1.0237978380566926
# BBOX Regression Loss:  0.008888323682074997
# Classification Loss:  1.0188065153179746
# BBOX Regression Loss:  0.008748528390763101
# Classification Loss:  1.0140138860732788
# BBOX Regression Loss:  0.008613207838131942
# Classification Loss:  1.009344361957751
# BBOX Regression Loss:  0.008480738286799627
# Classification Loss:  1.0046898364411765
# BBOX Regression Loss:  0.008349496961617462
# Classification Loss:  1.0001993852221434
# BBOX Regression Loss:  0.008221476349381753
# Classification Loss:  0.9959627169149893
# BBOX Regression Loss:  0.008099596256092778
# Classification Loss:  0.9918663739434286
# BBOX Regression Loss:  0.00798167307786599
# Classification Loss:  0.987863522305141
# BBOX Regression Loss:  0.007866030345193994
# Classification Loss:  0.9839726250147834
# BBOX Regression Loss:  0.0077537526630934465
# Classification Loss:  0.9801498683514417
# BBOX Regression Loss:  0.0076439107049182265
# Classification Loss:  0.976472248283886
# BBOX Regression Loss:  0.007537585854797919
# Classification Loss:  0.9729142025263624
# BBOX Regression Loss:  0.007434640275371081
# Classification Loss:  0.9694363668388
# BBOX Regression Loss:  0.007334173770828379
# Classification Loss:  0.9660698425276347
# BBOX Regression Loss:  0.007238139508774986
# Classification Loss:  0.9629339709566027
# BBOX Regression Loss:  0.007146990764196271
# Classification Loss:  0.9597766311080367
# BBOX Regression Loss:  0.007056675320340588
# Classification Loss:  0.9567047323108528
# BBOX Regression Loss:  0.006968195623442255
# Classification Loss:  0.9537098991527478
# BBOX Regression Loss:  0.006882217934025326
# Classification Loss:  0.9507906836824693
# BBOX Regression Loss:  0.006798380397323583
# Classification Loss:  0.9479163966976011
# BBOX Regression Loss:  0.006715874609203986
# Classification Loss:  0.9450955056084528
# BBOX Regression Loss:  0.006634871756202281
# Classification Loss:  0.9423695969535127
# BBOX Regression Loss:  0.006556067583538652
# Classification Loss:  0.939668936406035
# BBOX Regression Loss:  0.006478321337267573
# Classification Loss:  0.9370314206832494
# BBOX Regression Loss:  0.006402132864840646
# Classification Loss:  0.9344578341928045
# BBOX Regression Loss:  0.006327563898284334
# Classification Loss:  0.9319339449317365
# BBOX Regression Loss:  0.006254360038841635
# Classification Loss:  0.9294694903129084
# BBOX Regression Loss:  0.006182819295610624
# Classification Loss:  0.9270714763272637
# BBOX Regression Loss:  0.006112747639292973
# Classification Loss:  0.9247132946050151
# BBOX Regression Loss:  0.006044011253155636
# Classification Loss:  0.922429550429921
# BBOX Regression Loss:  0.005977611028485829
# Classification Loss:  0.9202437147751353
# BBOX Regression Loss:  0.005913560178522325
# Classification Loss:  0.9180823382789159
# BBOX Regression Loss:  0.005850675121059173
# Classification Loss:  0.915969647098572
# BBOX Regression Loss:  0.005789033141338364
# Classification Loss:  0.9139014762660068
# BBOX Regression Loss:  0.005728745047790566
# Classification Loss:  0.9118685601306269
# BBOX Regression Loss:  0.0056697840007489606
# Classification Loss:  0.9098854282363452
# BBOX Regression Loss:  0.0056122782598084725
# Classification Loss:  0.9079435413719243
# BBOX Regression Loss:  0.005555887493693334
# Classification Loss:  0.9060295079641296
# BBOX Regression Loss:  0.0055005594154828
# Classification Loss:  0.904164640441068
# BBOX Regression Loss:  0.005446421112747784
# Classification Loss:  0.9023246965791597
# BBOX Regression Loss:  0.0053932551834841224
# Classification Loss:  0.9005231166490105
# BBOX Regression Loss:  0.005341210256669854
# Classification Loss:  0.8987574210873356
# BBOX Regression Loss:  0.005290115205339914
# Classification Loss:  0.8970211008661072
# BBOX Regression Loss:  0.005239835504733888
# Classification Loss:  0.8953116168240569
# BBOX Regression Loss:  0.005190344996369883
# Classification Loss:  0.8936362792791785
# BBOX Regression Loss:  0.005141948854619706
# Classification Loss:  0.8919878679911294
# BBOX Regression Loss:  0.00031916325980866397
# Classification Loss:  0.7282311333550346
# BBOX Regression Loss:  0.00030814310604775395
# Classification Loss:  0.728332339392768
# BBOX Regression Loss:  0.00029870763903966656
# Classification Loss:  0.7277626414357882
# BBOX Regression Loss:  0.00029003565346270247
# Classification Loss:  0.7276980488388627
# BBOX Regression Loss:  0.0002862687829743932
# Classification Loss:  0.7275240071614582
# BBOX Regression Loss:  0.0002796639021440053
# Classification Loss:  0.7273851853829844
# BBOX Regression Loss:  0.0002746654543828554
# Classification Loss:  0.7273858923129934
# BBOX Regression Loss:  0.0002714462336842661
# Classification Loss:  0.7272281849825823
# BBOX Regression Loss:  0.0002671337297469868
# Classification Loss:  0.7271995026388287
# BBOX Regression Loss:  0.0002644124447747513
# Classification Loss:  0.7271891685768409
# BBOX Regression Loss:  0.000264638646345849
# Classification Loss:  0.7272073264073844
# BBOX Regression Loss:  0.00026573741989624163
# Classification Loss:  0.7272271762659521
# BBOX Regression Loss:  0.0002653531159706774
# Classification Loss:  0.7272285559238533
# BBOX Regression Loss:  0.0002647535613043204
# Classification Loss:  0.7272063941551896
# BBOX Regression Loss:  0.0002653351342190563
# Classification Loss:  0.7271655268727998
# BBOX Regression Loss:  0.00026502217386021383
# Classification Loss:  0.7271053729233918
# BBOX Regression Loss:  0.0002644323541991786
# Classification Loss:  0.7270386618986109
# BBOX Regression Loss:  0.0002640946230701642
# Classification Loss:  0.7269681302608286
# BBOX Regression Loss:  0.00026285583362143056
# Classification Loss:  0.7268936242741219
# BBOX Regression Loss:  0.00026120585260084933
# Classification Loss:  0.7268134936579952
# BBOX Regression Loss:  0.00025906402443583263
# Classification Loss:  0.7267300789108142
# BBOX Regression Loss:  0.0002585990069847968
# Classification Loss:  0.7266443143388639
# BBOX Regression Loss:  0.00025777424244741024
# Classification Loss:  0.7265590597082068
# BBOX Regression Loss:  0.00025568609686430404
# Classification Loss:  0.7264725985350432
# BBOX Regression Loss:  0.0002542369031795749
# Classification Loss:  0.7263860106291595
# BBOX Regression Loss:  0.00025415632202478386
# Classification Loss:  0.7262997070269027
# BBOX Regression Loss:  0.0002522932243532155
# Classification Loss:  0.7262140153693891
# BBOX Regression Loss:  0.00025017191458828546
# Classification Loss:  0.7261287711915516
# BBOX Regression Loss:  0.0002478830843431207
# Classification Loss:  0.7260442144264816
# BBOX Regression Loss:  0.00024551517059911553
# Classification Loss:  0.7259613319679543
# BBOX Regression Loss:  0.00024397891062660098
# Classification Loss:  0.7258770563269173
# BBOX Regression Loss:  0.0002454417245139161
# Classification Loss:  0.7257942795753479
# BBOX Regression Loss:  0.00024447358233224925
# Classification Loss:  0.7257117463014476
# BBOX Regression Loss:  0.000242687604331243
# Classification Loss:  0.7256287335830057
# BBOX Regression Loss:  0.00024088978190862
# Classification Loss:  0.7255468148529215
# BBOX Regression Loss:  0.00024029522494186834
# Classification Loss:  0.7254664631046878
# BBOX Regression Loss:  0.00023841125502794592
# Classification Loss:  0.7253868393234544
# BBOX Regression Loss:  0.00023644857147625024
# Classification Loss:  0.7253087820830169
# BBOX Regression Loss:  0.0002345270630244629
# Classification Loss:  0.7252313630193725
# BBOX Regression Loss:  0.00023320698644965887
# Classification Loss:  0.7251554545649777
# BBOX Regression Loss:  0.00023321485337855964
# Classification Loss:  0.7250799894117513
# BBOX Regression Loss:  0.00023169209269028178
# Classification Loss:  0.7250057852877932
# BBOX Regression Loss:  0.00022985089428299312
# Classification Loss:  0.7249331572053763
# BBOX Regression Loss:  0.0002284234755371481
# Classification Loss:  0.7248610926798297
# BBOX Regression Loss:  0.00022844156533970264
# Classification Loss:  0.7247897120660226
# BBOX Regression Loss:  0.00022793415294219282
# Classification Loss:  0.7247189736788592
# BBOX Regression Loss:  0.00022665050164763387
# Classification Loss:  0.7246496648465299
# BBOX Regression Loss:  0.000225134031203242
# Classification Loss:  0.7245807693328385
# BBOX Regression Loss:  0.00022524685246232145
# Classification Loss:  0.7245111322727332
# BBOX Regression Loss:  0.00022445027143866924
# Classification Loss:  0.7244427528381348
# BBOX Regression Loss:  0.00022311109187826784
# Classification Loss:  0.7243753289172159
# BBOX Regression Loss:  0.00022156013716794973
# Classification Loss:  0.7243090185344729
# BBOX Regression Loss:  0.00022065596632883316
# Classification Loss:  0.7242436215062811
# BBOX Regression Loss:  0.00022083088154847057
# Classification Loss:  0.7241795593491961
# BBOX Regression Loss:  0.0002198884459149707
# Classification Loss:  0.7241168297661675
# BBOX Regression Loss:  0.00021861218072772123
# Classification Loss:  0.7240550756454468
# BBOX Regression Loss:  0.0002185565913447056
# Classification Loss:  0.7239942580403408
# BBOX Regression Loss:  0.0002177953232575736
# Classification Loss:  0.72393410257605
# BBOX Regression Loss:  0.00021672124202127584
# Classification Loss:  0.7238753295438662

# %% [markdown]
# ## 想要Train VOC,COCO可以參考原Github:https://github.com/amdegroot/ssd.pytorch
